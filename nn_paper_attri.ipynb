# %%
import torch
from torch.utils import data

import numpy as np
import time, os

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline

# %%
import json

with open('train.json') as fin:
    train_data = json.load(fin)
    
print(len(train_data))
# Out:
# 26108

# %%
N_KEYWORDS= 500
N_VENUES = 470
N_AUTHORS = 2302
RANDOM_STATE = 1

# %%
def process_data(data):
    processed_features = []
    labels = []
    for paper_id, paper_val in data.items():
        venue = paper_val['venue'] if paper_val['venue'] else -1
        year = paper_val['year']
        kw_ids = paper_val['keywords']
        coauthors = paper_val['author']
        for target_author in coauthors:
            feature = np.zeros((1+1+N_KEYWORDS+N_AUTHORS,))
            feature[0] = venue / N_VENUES
            feature[1] = year / 2022
            for kw_id in kw_ids:
                feature[2+kw_id] = 1
            for author_id in coauthors:
                if author_id != target_author:
                    feature[502+author_id] = 1
            processed_features.append(feature)
            labels.append(target_author)
    return processed_features, labels

# %%
train_processed = process_data(train_data)
feature_processed, labels_processed = train_processed
print(len(feature_processed))
print(len(labels_processed))
# Out:
# 48000
# 48000

# %%
feature_processed = torch.from_numpy(np.array(feature_processed)).float()
labels_processed = torch.from_numpy(np.array(labels_processed)).long()

# %%
print(feature_processed[0])
print(len(feature_processed[0]))
# Out:
# tensor([-0.0021,  0.9975,  0.0000,  ...,  0.0000,  0.0000,  0.0000])
# 2804

# %%
print(labels_processed[0])
# Out:
# tensor(1605)

# %%
# processedset = []
# for i in range(len(feature_processed)):
#     processedset.append((feature_processed[i], labels_processed[i]))

# %%
# print(len(processedset))
# print(processedset[0])

# %%
# split into train and val
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(feature_processed, labels_processed, 
                                                  test_size=0.33, random_state=RANDOM_STATE*100)

# %%
print(len(X_train), len(y_train))
print(len(X_val), len(y_val))
# Out:
# 32160 32160
# 15840 15840

# %%
trainset = []
testset = []

for i in range(len(X_train)):
    trainset.append((X_train[i], y_train[i]))
    
for i in range(len(X_val)):
    testset.append((X_val[i], y_val[i]))

# %%
train_loader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True)
test_loader = torch.utils.data.DataLoader(testset, batch_size=128, shuffle=False)

# %%
papers, labels = iter(train_loader).next()

# %%
print(papers)
print(papers.size())
# Out:
# tensor([[0.0128, 0.9960, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.2532, 0.9921, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0234, 0.9931, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0617, 0.9926, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0213, 0.9946, 1.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.5915, 0.9941, 0.0000,  ..., 0.0000, 0.0000, 0.0000]])
# torch.Size([128, 2804])

# %%
print(labels)
print(labels.size())
# Out:
# tensor([ 879, 1186, 1853, 1577,  195, 1185,  115,   61,  209,  420, 1055,  647,
#          261,  138,  745, 1538, 1816, 1615, 1858,  352, 1583,  668, 2238, 2196,
#          209, 1204,  572, 1065,  275, 1821,  421,  438, 2115,  290,  868,  326,
#         1450,  287, 1703,  811,  404, 1927, 1821, 1345,  769, 1483, 1096,  303,
#         1488,  307,  888, 1587,  898, 1055, 1506, 1326, 2180,  644,   83,  105,
#          931,  619, 1267,  374, 1585,  125,  623, 1069,  158, 1034,  528, 2039,
#         1083, 2223, 1739,  499, 1851, 1326,  249, 1495, 1184,  864,  106, 1895,
#          808, 1998, 1125,  815,  675,  813, 2069, 1948, 2176, 2011,  665,  486,
#         1520, 1757, 1367, 1118, 1586,  838, 1456,  736,  365, 1742, 1983, 1934,
#         1683,  608, 1204,  630,  561,   18, 1095, 1914, 1055,  858, 1578, 2261,
#         1479, 1880, 1429,  444,   88,  192,  711, 1194])
# torch.Size([128])

# %%
import torch.nn as nn
import torch.nn.functional as F

class LogisticRegressionModel(nn.Module):
    
    def __init__(self, n_features, n_classes):
        super(LogisticRegressionModel, self).__init__()
        
        # Register weight matrix and bias term as model parameters - automatically tracks operations for gradient computation
        self.W = torch.nn.Parameter(torch.nn.init.xavier_uniform_(torch.empty([n_features, n_classes]))) # Weights 
        self.b = torch.nn.Parameter(torch.zeros([n_classes])) # Biases
        
    def forward(self, x):
        """
        Forward pass for logistic regression.
        Input: Tensor x of shape []
        Output: Logits W @ x + b
        """
        batch_size = x.shape[0]
        
        x = x.view(batch_size, -1) # Flatten data, retaining batch size
        out = torch.matmul(x, self.W) + self.b # compute scores 
        return out

# %%
n_features, n_classes = 1+1+N_KEYWORDS+N_AUTHORS, N_AUTHORS
logistic_regression_model = LogisticRegressionModel(n_features, n_classes)

for p in logistic_regression_model.parameters():
    print(p.shape)
# Out:
# torch.Size([2804, 2302])
# torch.Size([2302])

# %%
def test(model, criterion, test_loader):
    
    test_loss = 0.
    test_preds, test_labels = list(), list()
    for i, data in enumerate(test_loader):
        x, labels = data
        
        with torch.no_grad():
            logits = model(x)    # Compute scores
            predictions = torch.argmax(logits, dim=1)
            test_loss += criterion(input=logits, target=labels).item()
            test_preds.append(predictions)
            test_labels.append(labels)
            
    test_preds = torch.cat(test_preds)
    test_labels = torch.cat(test_labels)
    
    test_accuracy = torch.eq(test_preds, test_labels).float().mean().item()
    
    print('[TEST] Mean loss {:.4f} | Accuracy {:.4f}'.format(test_loss/len(test_loader), test_accuracy))



def train(model, train_loader, test_loader, optimizer, n_epochs=10):
    """
    Generic training loop for supervised multiclass learning
    """
    LOG_INTERVAL = 250
    running_loss, running_accuracy = list(), list()
    start_time = time.time()
    criterion = torch.nn.CrossEntropyLoss()
    
    for epoch in range(n_epochs): # Loop over training dataset 'n_epochs' times
        epoch_loss = 0.
        
        for i, data in enumerate(train_loader): # Loop over elements in training set
            x, labels = data
            logits = model(x)
            predictions = torch.argmax(logits, dim=1)
            train_acc = torch.mean(torch.eq(predictions, labels).float()).item()
            loss = criterion(input=logits, target=labels)
            
            loss.backward()          # Backward pass (compute parameter gradients)
            optimizer.step()         # Update weight parameter using SGD
            optimizer.zero_grad()    # Reset gradients to zero for next iteration
            
            # ============================================================================
            # You can safely ignore the boilerplate code below - just reports metrics over
            # training and test sets

            running_loss.append(loss.item())
            running_accuracy.append(train_acc)

            epoch_loss += loss.item()

            if i % LOG_INTERVAL == 0:  # Log training stats
                deltaT = time.time() - start_time
                mean_loss = epoch_loss / (i+1)
                print('[TRAIN] Epoch {} [{}/{}]| Mean loss {:.4f} | Train accuracy {:.5f} | Time {:.2f} s'.format(epoch, 
                    i, len(train_loader), mean_loss, train_acc, deltaT))

        print('Epoch complete! Mean loss: {:.4f}'.format(epoch_loss/len(train_loader)))

        test(model, criterion, test_loader)
        
    return running_loss, running_accuracy

# %%
# optimizer = torch.optim.SGD(logistic_regression_model.parameters(), lr=1e-2, momentum=0.9)
optimizer = torch.optim.SGD(logistic_regression_model.parameters(), lr=1e-1, momentum=0.9)


lr_loss, lr_acc = train(logistic_regression_model, train_loader, test_loader, optimizer)
# Out:
# [TRAIN] Epoch 0 [0/252]| Mean loss 7.7522 | Train accuracy 0.00000 | Time 0.10 s
# [TRAIN] Epoch 0 [250/252]| Mean loss 7.5008 | Train accuracy 0.01562 | Time 22.61 s
# Epoch complete! Mean loss: 7.5001
# [TEST] Mean loss 7.3265 | Accuracy 0.0196
# [TRAIN] Epoch 1 [0/252]| Mean loss 7.1115 | Train accuracy 0.03906 | Time 27.80 s
# [TRAIN] Epoch 1 [250/252]| Mean loss 7.0016 | Train accuracy 0.05469 | Time 50.33 s
# Epoch complete! Mean loss: 7.0006
# [TEST] Mean loss 7.1103 | Accuracy 0.0370
# [TRAIN] Epoch 2 [0/252]| Mean loss 6.6240 | Train accuracy 0.10156 | Time 55.51 s
# [TRAIN] Epoch 2 [250/252]| Mean loss 6.6195 | Train accuracy 0.05469 | Time 77.97 s
# Epoch complete! Mean loss: 6.6187
# [TEST] Mean loss 6.9321 | Accuracy 0.0485
# [TRAIN] Epoch 3 [0/252]| Mean loss 6.2001 | Train accuracy 0.14062 | Time 83.21 s
# [TRAIN] Epoch 3 [250/252]| Mean loss 6.2757 | Train accuracy 0.10156 | Time 105.79 s
# Epoch complete! Mean loss: 6.2742
# [TEST] Mean loss 6.7732 | Accuracy 0.0580
# [TRAIN] Epoch 4 [0/252]| Mean loss 6.1183 | Train accuracy 0.09375 | Time 110.97 s
# [TRAIN] Epoch 4 [250/252]| Mean loss 5.9583 | Train accuracy 0.07031 | Time 133.44 s
# Epoch complete! Mean loss: 5.9577
# [TEST] Mean loss 6.6330 | Accuracy 0.0655
# [TRAIN] Epoch 5 [0/252]| Mean loss 5.7767 | Train accuracy 0.18750 | Time 138.62 s
# [TRAIN] Epoch 5 [250/252]| Mean loss 5.6630 | Train accuracy 0.16406 | Time 161.06 s
# Epoch complete! Mean loss: 5.6635
# [TEST] Mean loss 6.5047 | Accuracy 0.0752
# [TRAIN] Epoch 6 [0/252]| Mean loss 5.5141 | Train accuracy 0.18750 | Time 166.27 s
# [TRAIN] Epoch 6 [250/252]| Mean loss 5.3880 | Train accuracy 0.13281 | Time 188.81 s
# Epoch complete! Mean loss: 5.3863
# [TEST] Mean loss 6.3890 | Accuracy 0.0792
# [TRAIN] Epoch 7 [0/252]| Mean loss 5.3183 | Train accuracy 0.16406 | Time 193.99 s
# [TRAIN] Epoch 7 [250/252]| Mean loss 5.1295 | Train accuracy 0.17969 | Time 216.51 s
# Epoch complete! Mean loss: 5.1288
# [TEST] Mean loss 6.2814 | Accuracy 0.0847
# [TRAIN] Epoch 8 [0/252]| Mean loss 4.8236 | Train accuracy 0.24219 | Time 221.68 s
# [TRAIN] Epoch 8 [250/252]| Mean loss 4.8869 | Train accuracy 0.17969 | Time 244.13 s
# Epoch complete! Mean loss: 4.8873
# [TEST] Mean loss 6.1829 | Accuracy 0.0903
# [TRAIN] Epoch 9 [0/252]| Mean loss 4.7229 | Train accuracy 0.28125 | Time 249.30 s
# [TRAIN] Epoch 9 [250/252]| Mean loss 4.6597 | Train accuracy 0.22656 | Time 271.77 s
# Epoch complete! Mean loss: 4.6588
# [TEST] Mean loss 6.0935 | Accuracy 0.0936

# %%
optimizer = torch.optim.SGD(logistic_regression_model.parameters(), lr=2e-1, momentum=0.9)


lr_loss, lr_acc = train(logistic_regression_model, train_loader, test_loader, optimizer)
# Out:
# [TRAIN] Epoch 0 [0/252]| Mean loss 1.8138 | Train accuracy 0.72656 | Time 0.13 s
# [TRAIN] Epoch 0 [250/252]| Mean loss 2.0028 | Train accuracy 0.67188 | Time 22.66 s
# Epoch complete! Mean loss: 2.0031
# [TEST] Mean loss 5.2230 | Accuracy 0.1312
# [TRAIN] Epoch 1 [0/252]| Mean loss 1.9688 | Train accuracy 0.74219 | Time 27.84 s
# [TRAIN] Epoch 1 [250/252]| Mean loss 1.8728 | Train accuracy 0.64062 | Time 50.30 s
# Epoch complete! Mean loss: 1.8723
# [TEST] Mean loss 5.1958 | Accuracy 0.1326
# [TRAIN] Epoch 2 [0/252]| Mean loss 1.6599 | Train accuracy 0.76562 | Time 55.48 s
# [TRAIN] Epoch 2 [250/252]| Mean loss 1.7517 | Train accuracy 0.70312 | Time 77.99 s
# Epoch complete! Mean loss: 1.7523
# [TEST] Mean loss 5.1735 | Accuracy 0.1341
# [TRAIN] Epoch 3 [0/252]| Mean loss 1.5628 | Train accuracy 0.77344 | Time 83.17 s
# [TRAIN] Epoch 3 [250/252]| Mean loss 1.6429 | Train accuracy 0.74219 | Time 105.67 s
# Epoch complete! Mean loss: 1.6437
# [TEST] Mean loss 5.1532 | Accuracy 0.1350
# [TRAIN] Epoch 4 [0/252]| Mean loss 1.6058 | Train accuracy 0.82812 | Time 110.85 s
# [TRAIN] Epoch 4 [250/252]| Mean loss 1.5429 | Train accuracy 0.77344 | Time 133.34 s
# Epoch complete! Mean loss: 1.5433
# [TEST] Mean loss 5.1359 | Accuracy 0.1358
# [TRAIN] Epoch 5 [0/252]| Mean loss 1.2167 | Train accuracy 0.85156 | Time 138.51 s
# [TRAIN] Epoch 5 [250/252]| Mean loss 1.4510 | Train accuracy 0.78906 | Time 161.02 s
# Epoch complete! Mean loss: 1.4515
# [TEST] Mean loss 5.1210 | Accuracy 0.1376
# [TRAIN] Epoch 6 [0/252]| Mean loss 1.2036 | Train accuracy 0.88281 | Time 166.20 s
# [TRAIN] Epoch 6 [250/252]| Mean loss 1.3670 | Train accuracy 0.82031 | Time 188.60 s
# Epoch complete! Mean loss: 1.3666
# [TEST] Mean loss 5.1089 | Accuracy 0.1375
# [TRAIN] Epoch 7 [0/252]| Mean loss 1.2991 | Train accuracy 0.83594 | Time 193.78 s
# [TRAIN] Epoch 7 [250/252]| Mean loss 1.2898 | Train accuracy 0.81250 | Time 216.25 s
# Epoch complete! Mean loss: 1.2898
# [TEST] Mean loss 5.1012 | Accuracy 0.1410
# [TRAIN] Epoch 8 [0/252]| Mean loss 1.0400 | Train accuracy 0.89844 | Time 221.48 s
# [TRAIN] Epoch 8 [250/252]| Mean loss 1.2186 | Train accuracy 0.89844 | Time 244.06 s
# Epoch complete! Mean loss: 1.2187
# [TEST] Mean loss 5.0902 | Accuracy 0.1415
# [TRAIN] Epoch 9 [0/252]| Mean loss 1.1405 | Train accuracy 0.85156 | Time 249.24 s
# [TRAIN] Epoch 9 [250/252]| Mean loss 1.1526 | Train accuracy 0.81250 | Time 271.74 s
# Epoch complete! Mean loss: 1.1536
# [TEST] Mean loss 5.0827 | Accuracy 0.1433

# %%
optimizer = torch.optim.SGD(logistic_regression_model.parameters(), lr=2e-1, momentum=0.9)


lr_loss, lr_acc = train(logistic_regression_model, train_loader, test_loader, optimizer)
# Out:
# [TRAIN] Epoch 0 [0/252]| Mean loss 1.0186 | Train accuracy 0.92188 | Time 0.13 s
# [TRAIN] Epoch 0 [250/252]| Mean loss 1.0939 | Train accuracy 0.89062 | Time 22.71 s
# Epoch complete! Mean loss: 1.0940
# [TEST] Mean loss 5.0788 | Accuracy 0.1449
# [TRAIN] Epoch 1 [0/252]| Mean loss 1.0770 | Train accuracy 0.88281 | Time 27.89 s
# [TRAIN] Epoch 1 [250/252]| Mean loss 1.0382 | Train accuracy 0.84375 | Time 50.38 s
# Epoch complete! Mean loss: 1.0398
# [TEST] Mean loss 5.0735 | Accuracy 0.1453
# [TRAIN] Epoch 2 [0/252]| Mean loss 0.9530 | Train accuracy 0.94531 | Time 55.56 s
# [TRAIN] Epoch 2 [250/252]| Mean loss 0.9865 | Train accuracy 0.92969 | Time 78.08 s
# Epoch complete! Mean loss: 0.9874
# [TEST] Mean loss 5.0685 | Accuracy 0.1468
# [TRAIN] Epoch 3 [0/252]| Mean loss 0.8784 | Train accuracy 0.96094 | Time 83.25 s
# [TRAIN] Epoch 3 [250/252]| Mean loss 0.9382 | Train accuracy 0.92969 | Time 105.69 s
# Epoch complete! Mean loss: 0.9377
# [TEST] Mean loss 5.0665 | Accuracy 0.1482
# [TRAIN] Epoch 4 [0/252]| Mean loss 0.7671 | Train accuracy 0.94531 | Time 110.87 s
# [TRAIN] Epoch 4 [250/252]| Mean loss 0.8935 | Train accuracy 0.92969 | Time 133.37 s
# Epoch complete! Mean loss: 0.8929
# [TEST] Mean loss 5.0618 | Accuracy 0.1489
# [TRAIN] Epoch 5 [0/252]| Mean loss 0.8685 | Train accuracy 0.92188 | Time 138.56 s
# [TRAIN] Epoch 5 [250/252]| Mean loss 0.8513 | Train accuracy 0.86719 | Time 161.07 s
# Epoch complete! Mean loss: 0.8514
# [TEST] Mean loss 5.0607 | Accuracy 0.1513
# [TRAIN] Epoch 6 [0/252]| Mean loss 0.7746 | Train accuracy 0.93750 | Time 166.25 s
# [TRAIN] Epoch 6 [250/252]| Mean loss 0.8126 | Train accuracy 0.89844 | Time 188.72 s
# Epoch complete! Mean loss: 0.8121
# [TEST] Mean loss 5.0608 | Accuracy 0.1522
# [TRAIN] Epoch 7 [0/252]| Mean loss 0.7147 | Train accuracy 0.96094 | Time 193.90 s
# [TRAIN] Epoch 7 [250/252]| Mean loss 0.7764 | Train accuracy 0.94531 | Time 216.37 s
# Epoch complete! Mean loss: 0.7759
# [TEST] Mean loss 5.0597 | Accuracy 0.1524
# [TRAIN] Epoch 8 [0/252]| Mean loss 0.6592 | Train accuracy 0.96875 | Time 221.59 s
# [TRAIN] Epoch 8 [250/252]| Mean loss 0.7421 | Train accuracy 0.93750 | Time 244.06 s
# Epoch complete! Mean loss: 0.7424
# [TEST] Mean loss 5.0607 | Accuracy 0.1535
# [TRAIN] Epoch 9 [0/252]| Mean loss 0.7476 | Train accuracy 0.96094 | Time 249.27 s
# [TRAIN] Epoch 9 [250/252]| Mean loss 0.7107 | Train accuracy 0.97656 | Time 271.85 s
# Epoch complete! Mean loss: 0.7108
# [TEST] Mean loss 5.0607 | Accuracy 0.1547

# %%
optimizer = torch.optim.SGD(logistic_regression_model.parameters(), lr=2e-1, momentum=0.9)


lr_loss, lr_acc = train(logistic_regression_model, train_loader, test_loader, optimizer)
# Out:
# [TRAIN] Epoch 0 [0/252]| Mean loss 0.6512 | Train accuracy 0.96875 | Time 0.12 s
# [TRAIN] Epoch 0 [250/252]| Mean loss 0.6819 | Train accuracy 0.95312 | Time 22.72 s
# Epoch complete! Mean loss: 0.6823
# [TEST] Mean loss 5.0627 | Accuracy 0.1566
# [TRAIN] Epoch 1 [0/252]| Mean loss 0.6101 | Train accuracy 0.96875 | Time 27.90 s
# [TRAIN] Epoch 1 [250/252]| Mean loss 0.6542 | Train accuracy 0.96094 | Time 50.38 s
# Epoch complete! Mean loss: 0.6539
# [TEST] Mean loss 5.0639 | Accuracy 0.1573
# [TRAIN] Epoch 2 [0/252]| Mean loss 0.6255 | Train accuracy 0.96094 | Time 55.55 s
# [TRAIN] Epoch 2 [250/252]| Mean loss 0.6281 | Train accuracy 0.95312 | Time 78.02 s
# Epoch complete! Mean loss: 0.6281
# [TEST] Mean loss 5.0644 | Accuracy 0.1582
# [TRAIN] Epoch 3 [0/252]| Mean loss 0.6035 | Train accuracy 0.94531 | Time 83.20 s
# [TRAIN] Epoch 3 [250/252]| Mean loss 0.6036 | Train accuracy 0.96875 | Time 105.67 s
# Epoch complete! Mean loss: 0.6032
# [TEST] Mean loss 5.0643 | Accuracy 0.1597
# [TRAIN] Epoch 4 [0/252]| Mean loss 0.5730 | Train accuracy 0.97656 | Time 110.85 s
# [TRAIN] Epoch 4 [250/252]| Mean loss 0.5808 | Train accuracy 0.94531 | Time 133.32 s
# Epoch complete! Mean loss: 0.5805
# [TEST] Mean loss 5.0654 | Accuracy 0.1603
# [TRAIN] Epoch 5 [0/252]| Mean loss 0.4871 | Train accuracy 0.97656 | Time 138.49 s
# [TRAIN] Epoch 5 [250/252]| Mean loss 0.5588 | Train accuracy 0.99219 | Time 160.96 s
# Epoch complete! Mean loss: 0.5591
# [TEST] Mean loss 5.0698 | Accuracy 0.1607
# [TRAIN] Epoch 6 [0/252]| Mean loss 0.5188 | Train accuracy 0.98438 | Time 166.14 s
# [TRAIN] Epoch 6 [250/252]| Mean loss 0.5387 | Train accuracy 0.96094 | Time 188.58 s
# Epoch complete! Mean loss: 0.5385
# [TEST] Mean loss 5.0697 | Accuracy 0.1619
# [TRAIN] Epoch 7 [0/252]| Mean loss 0.4465 | Train accuracy 1.00000 | Time 193.77 s
# [TRAIN] Epoch 7 [250/252]| Mean loss 0.5194 | Train accuracy 0.98438 | Time 216.26 s
# Epoch complete! Mean loss: 0.5195
# [TEST] Mean loss 5.0715 | Accuracy 0.1623
# [TRAIN] Epoch 8 [0/252]| Mean loss 0.5155 | Train accuracy 0.98438 | Time 221.44 s
# [TRAIN] Epoch 8 [250/252]| Mean loss 0.5014 | Train accuracy 0.97656 | Time 243.91 s
# Epoch complete! Mean loss: 0.5014
# [TEST] Mean loss 5.0751 | Accuracy 0.1625
# [TRAIN] Epoch 9 [0/252]| Mean loss 0.4815 | Train accuracy 0.99219 | Time 249.09 s
# [TRAIN] Epoch 9 [250/252]| Mean loss 0.4842 | Train accuracy 0.97656 | Time 271.63 s
# Epoch complete! Mean loss: 0.4839
# [TEST] Mean loss 5.0791 | Accuracy 0.1628

# %%
for p in logistic_regression_model.parameters():
    print(p)
    print(p.shape)
# Out:
# Parameter containing:
# tensor([[-0.2999, -0.1844,  0.1120,  ..., -0.2517, -0.0123, -0.1958],
#         [-0.3949, -0.1703,  0.2840,  ...,  0.1621, -0.0648,  0.0138],
#         [ 0.1238,  0.3956, -0.0494,  ..., -0.1504, -0.0709, -0.0695],
#         ...,
#         [-0.0333,  0.0144, -0.0232,  ..., -0.6263,  0.0055, -0.0317],
#         [-0.0207, -0.0183,  0.0287,  ...,  0.0041, -0.1266, -0.0072],
#         [-0.0177,  0.0185, -0.0052,  ..., -0.0236, -0.0130, -0.5976]],
#        requires_grad=True)
# torch.Size([2804, 2302])
# Parameter containing:
# tensor([-0.3854, -0.1913,  0.2649,  ...,  0.1803, -0.0992,  0.0150],
#        requires_grad=True)
# torch.Size([2302])

# %%
with open('test.json') as fin:
    test_data = json.load(fin)

# %%
def process_test_data(test_data):
    processed_features = []
#     labels = []
    for paper_id, paper_val in test_data.items():
        venue = paper_val['venue'] if paper_val['venue'] else -1
        year = paper_val['year']
        kw_ids = paper_val['keywords']
        coauthors = paper_val['coauthor']
        target = paper_val['target']
        feature = np.zeros((1+1+N_KEYWORDS+N_AUTHORS,))
        feature[0] = venue / N_VENUES
        feature[1] = year / 2022
        for kw_id in kw_ids:
            feature[2+kw_id] = 1
        for author_id in coauthors:
            if author_id != target:
                feature[502+author_id] = 1
        
        processed_features.append(feature)
#         labels.append(target_author)
    return processed_features

# %%
test_processed = process_test_data(test_data)
print(len(test_processed))
# Out:
# 2000

# %%
print(test_processed[0])
# Out:
# [-0.00212766  0.9975272   0.         ...  0.          0.
#   0.        ]

# %%
print(len(test_processed))
print(len(test_processed[0]))
# Out:
# 2000
# 2804

# %%
test_tensor = torch.tensor(np.array(test_processed)).float()

# %%
predictions = torch.matmul(test_tensor, logistic_regression_model.W) + logistic_regression_model.b

# %%
print(predictions)
# Out:
# tensor([[ 0.5472, -1.5553,  1.8692,  ..., -1.4924,  1.1380,  1.6676],
#         [ 2.5158, -0.1334, -0.2301,  ..., -0.4333,  0.3597, -1.8677],
#         [-1.2355, -1.7690,  0.5425,  ..., -0.4461, -1.2335, -1.3483],
#         ...,
#         [-0.9730, -3.9031,  1.8500,  ..., -0.4102,  0.2619, -0.3934],
#         [ 2.2442, -0.1286, -0.2769,  ...,  0.5490,  1.7294,  1.1731],
#         [-2.7417, -1.5671, -0.2898,  ..., -0.0727, -2.3068,  0.8413]],
#        grad_fn=<AddBackward0>)

# %%
predictions_np = predictions.tolist()

# %%
print(predictions.shape)
# Out:
# torch.Size([2000, 2302])

# %%
result_pred = []

for paper_id, paper_val in test_data.items():
    paper_id = int(paper_id)
    target = paper_val['target']
    prob = predictions_np[paper_id][target]
    print(paper_id, prob)
    result_pred.append([paper_id, prob])

print(len(result_pred))
print(len(result_pred[0]))
# Out:
# 0 5.340229511260986
# 1 1.9624106884002686
# 2 4.263720512390137
# 3 4.271944046020508
# 4 0.46411752700805664
# 5 -2.8767380714416504
# 6 1.908257246017456
# 7 -1.4947010278701782
# 8 -1.047459602355957
# 9 1.1964439153671265
# 10 2.9688870906829834
# 11 -2.237889289855957
# 12 2.3981871604919434
# 13 8.019248962402344
# 14 -2.4551541805267334
# 15 3.596299409866333
# 16 7.90132474899292
# 17 4.073276042938232
# 18 8.261945724487305
# 19 5.49031400680542
# 20 -3.2315235137939453
# 21 -0.8711045384407043
# 22 2.635655641555786
# 23 1.6767030954360962
# 24 1.4345016479492188
# 25 -3.7307913303375244
# 26 -2.5175857543945312
# 27 -2.7298521995544434
# 28 3.005125045776367
# 29 -0.7947632074356079
# 30 5.274263381958008
# 31 7.646844863891602
# 32 2.0757951736450195
# 33 -1.546004295349121
# 34 1.5865020751953125
# 35 1.0566571950912476
# 36 8.098838806152344
# 37 -0.9434711933135986
# 38 -1.5629324913024902
# 39 5.069618225097656
# 40 4.684459686279297
# 41 9.150161743164062
# 42 0.6026682257652283
# 43 10.052952766418457
# 44 9.344369888305664
# 45 3.9054386615753174
# 46 6.359133243560791
# 47 -0.7004336714744568
# 48 2.056062936782837
# 49 5.449919700622559
# 50 6.864447116851807
# 51 3.025090217590332
# 52 6.719078063964844
# 53 1.1778206825256348
# 54 -0.24220386147499084
# 55 -1.9049466848373413
# 56 1.2243051528930664
# 57 6.474936008453369
# 58 -0.35372889041900635
# 59 1.7711149454116821
# 60 9.49891185760498
# 61 2.104994297027588
# 62 4.422652721405029
# 63 -0.32676973938941956
# 64 -0.5177826285362244
# 65 -0.19183818995952606
# 66 -0.22479234635829926
# 67 1.3693710565567017
# 68 2.8775711059570312
# 69 3.1525747776031494
# 70 -2.5674614906311035
# 71 -0.10689595341682434
# 72 2.185708522796631
# 73 1.0522218942642212
# 74 -0.06131899356842041
# 75 1.750710129737854
# 76 2.0933988094329834
# 77 10.068769454956055
# 78 10.729965209960938
# 79 4.810060977935791
# 80 3.178246259689331
# 81 11.044320106506348
# 82 -1.1029168367385864
# 83 -0.44818323850631714
# 84 -1.047600269317627
# 85 0.4062114953994751
# 86 -0.02722388505935669
# 87 2.5728759765625
# 88 -3.892810821533203
# 89 -0.8810635805130005
# 90 -1.0398221015930176
# 91 0.8186233043670654
# 92 4.234046459197998
# 93 3.9964993000030518
# 94 -0.4497483968734741
# 95 5.865293502807617
# 96 5.988752365112305
# 97 1.7166322469711304
# 98 6.0727715492248535
# 99 -1.6370742321014404
# 100 4.851236820220947
# 101 0.0006984472274780273
# 102 -3.42732834815979
# 103 4.7161545753479
# 104 3.160173177719116
# 105 3.7217512130737305
# 106 8.1378173828125
# 107 3.1678619384765625
# 108 0.2662034332752228
# 109 0.12985166907310486
# 110 1.0317233800888062
# 111 4.036983013153076
# 112 -3.863022804260254
# 113 -2.145057201385498
# 114 10.540891647338867
# 115 -0.6845554113388062
# 116 1.763027548789978
# 117 2.1401681900024414
# 118 9.875214576721191
# 119 -2.707188367843628
# 120 0.8859707713127136
# 121 -1.9506585597991943
# 122 -4.377468109130859
# 123 -2.1159145832061768
# 124 0.9222617149353027
# 125 6.71334171295166
# 126 3.8283772468566895
# 127 12.369694709777832
# 128 -2.464646339416504
# 129 4.969346046447754
# 130 6.125207901000977
# 131 2.6418187618255615
# 132 2.1069445610046387
# 133 4.47695779800415
# 134 0.1162371039390564
# 135 -0.6124662160873413
# 136 4.225095748901367
# 137 6.425024032592773
# 138 -0.5935310125350952
# 139 -2.698228359222412
# 140 3.583449125289917
# 141 7.486186981201172
# 142 1.5878828763961792
# 143 -0.38420426845550537
# 144 0.31957584619522095
# 145 3.8940043449401855
# 146 0.20118549466133118
# 147 1.2690095901489258
# 148 8.826900482177734
# 149 2.428623676300049
# 150 -1.4840210676193237
# 151 2.6658475399017334
# 152 2.7178702354431152
# 153 3.8033242225646973
# 154 0.26822149753570557
# 155 2.7641494274139404
# 156 2.3475375175476074
# 157 2.638962745666504
# 158 -2.3659508228302
# 159 -0.24428927898406982
# 160 2.657998561859131
# 161 5.714849472045898
# 162 5.920767784118652
# 163 0.31076499819755554
# 164 -2.02367901802063
# 165 -0.08062547445297241
# 166 1.7091840505599976
# 167 2.1567740440368652
# 168 8.589097023010254
# 169 -2.096346855163574
# 170 6.915455341339111
# 171 1.058782696723938
# 172 2.9569597244262695
# 173 2.864880084991455
# 174 3.8827428817749023
# 175 1.3229221105575562
# 176 0.43195295333862305
# 177 -0.9184889793395996
# 178 9.512397766113281
# 179 3.7405855655670166
# 180 4.081629753112793
# 181 -1.0972706079483032
# 182 0.7753348350524902
# 183 11.265826225280762
# 184 1.3381967544555664
# 185 -1.3330730199813843
# 186 0.16424188017845154
# 187 5.214014530181885
# 188 2.7008025646209717
# 189 0.7055566906929016
# 190 1.8469879627227783
# 191 1.816836953163147
# 192 4.480667591094971
# 193 3.1704325675964355
# 194 0.08705337345600128
# 195 -1.298836588859558
# 196 1.7406961917877197
# 197 1.488548994064331
# 198 -0.11538748443126678
# 199 7.380320072174072
# 200 -0.8848950266838074
# 201 5.025722503662109
# 202 0.04359593242406845
# 203 6.60177755355835
# 204 1.5047976970672607
# 205 6.766900539398193
# 206 3.2606441974639893
# 207 1.4997364282608032
# 208 4.838652610778809
# 209 8.264697074890137
# 210 -2.3077359199523926
# 211 3.201462984085083
# 212 3.7587413787841797
# 213 7.507776260375977
# 214 2.110191822052002
# 215 3.6251347064971924
# 216 3.2439723014831543
# 217 2.0314273834228516
# 218 -1.9266605377197266
# 219 -3.3274238109588623
# 220 2.786759376525879
# 221 6.1849493980407715
# 222 1.2053039073944092
# 223 -1.3879255056381226
# 224 2.682375907897949
# 225 7.609554290771484
# 226 13.318523406982422
# 227 10.106888771057129
# 228 2.569918155670166
# 229 2.573272466659546
# 230 4.44270133972168
# 231 1.0676138401031494
# 232 9.577200889587402
# 233 0.9555366635322571
# 234 -2.4243950843811035
# 235 7.099811553955078
# 236 2.6310150623321533
# 237 2.4367384910583496
# 238 -0.4981996715068817
# 239 2.848952293395996
# 240 -1.6207355260849
# 241 1.2399470806121826
# 242 0.09452348947525024
# 243 5.3438825607299805
# 244 -3.4909143447875977
# 245 0.7947577834129333
# 246 -1.356122612953186
# 247 1.2264026403427124
# 248 11.901321411132812
# 249 6.649490833282471
# 250 3.9681503772735596
# 251 8.302423477172852
# 252 1.984346866607666
# 253 2.2897303104400635
# 254 -3.166912794113159
# 255 1.8167409896850586
# 256 0.2872247099876404
# 257 9.143058776855469
# 258 8.497552871704102
# 259 -2.83807635307312
# 260 1.37209153175354
# 261 -0.1773722767829895
# 262 0.3489459455013275
# 263 3.968838691711426
# 264 9.681612014770508
# 265 4.5431413650512695
# 266 0.30153077840805054
# 267 0.581477165222168
# 268 5.1758904457092285
# 269 0.8636096715927124
# 270 9.230501174926758
# 271 4.517026901245117
# 272 -0.7950147390365601
# 273 2.3725152015686035
# 274 2.1991143226623535
# 275 4.825680255889893
# 276 3.0132453441619873
# 277 -0.9570170044898987
# 278 3.5985772609710693
# 279 8.782835006713867
# 280 4.577187538146973
# 281 0.7706081867218018
# 282 0.6390172243118286
# 283 3.304237127304077
# 284 -2.658696174621582
# 285 1.1096287965774536
# 286 7.845355987548828
# 287 0.6570816040039062
# 288 -0.16951286792755127
# 289 -0.5977268218994141
# 290 0.5552027225494385
# 291 10.256790161132812
# 292 5.683263301849365
# 293 0.14024552702903748
# 294 0.8640391230583191
# 295 8.176871299743652
# 296 1.9252984523773193
# 297 3.4816555976867676
# 298 3.2115418910980225
# 299 0.1545296162366867
# 300 1.1805315017700195
# 301 -0.8969964385032654
# 302 -0.005703061819076538
# 303 3.136169910430908
# 304 -1.4278028011322021
# 305 1.2213134765625
# 306 -1.1263495683670044
# 307 9.342501640319824
# 308 3.9483137130737305
# 309 -2.940294027328491
# 310 6.1670708656311035
# 311 -0.6564114689826965
# 312 2.6566784381866455
# 313 0.8016088604927063
# 314 0.5315201282501221
# 315 2.9635467529296875
# 316 0.21364985406398773
# 317 1.2284576892852783
# 318 -0.26139166951179504
# 319 1.0515823364257812
# 320 1.4156607389450073
# 321 5.818548679351807
# 322 5.87730598449707
# 323 -2.3950860500335693
# 324 0.3362882137298584
# 325 2.842355489730835
# 326 1.7738265991210938
# 327 5.590422630310059
# 328 -1.1188461780548096
# 329 3.0456528663635254
# 330 -2.513136386871338
# 331 1.6574283838272095
# 332 11.847198486328125
# 333 -0.9802353382110596
# 334 1.8145174980163574
# 335 12.081977844238281
# 336 -0.5777241587638855
# 337 1.2344985008239746
# 338 1.9684016704559326
# 339 1.0970804691314697
# 340 -0.9256042242050171
# 341 -1.7500704526901245
# 342 2.918607473373413
# 343 3.6320345401763916
# 344 0.735358476638794
# 345 1.1889410018920898
# 346 1.6840729713439941
# 347 1.5041145086288452
# 348 1.9723726511001587
# 349 0.7858474254608154
# 350 -3.2990171909332275
# 351 -1.4370956420898438
# 352 0.27038347721099854
# 353 4.537762641906738
# 354 -3.0639050006866455
# 355 2.896245241165161
# 356 2.055166006088257
# 357 1.276771903038025
# 358 -2.5915610790252686
# 359 0.2474338561296463
# 360 2.0166752338409424
# 361 -0.47746139764785767
# 362 10.919109344482422
# 363 -0.38938629627227783
# 364 -0.9634064435958862
# 365 -0.115353524684906
# 366 0.8308534622192383
# 367 7.443790435791016
# 368 -0.8042919039726257
# 369 1.0179829597473145
# 370 1.2367597818374634
# 371 -2.0315921306610107
# 372 1.1171061992645264
# 373 -0.34094923734664917
# 374 -1.068687915802002
# 375 2.0008647441864014
# 376 1.6403322219848633
# 377 1.8853838443756104
# 378 11.712818145751953
# 379 8.21094036102295
# 380 -1.1341723203659058
# 381 -1.3680970668792725
# 382 2.1123056411743164
# 383 -1.0893473625183105
# 384 3.6785783767700195
# 385 6.772745132446289
# 386 -0.7952988147735596
# 387 1.5532407760620117
# 388 2.771151542663574
# 389 -0.45555388927459717
# 390 -1.095527172088623
# 391 3.2204341888427734
# 392 -3.2614665031433105
# 393 3.7149744033813477
# 394 3.9651031494140625
# 395 7.777408123016357
# 396 -1.3871876001358032
# 397 7.019543647766113
# 398 0.5014379620552063
# 399 -2.3570773601531982
# 400 0.47751420736312866
# 401 1.1914684772491455
# 402 7.8481059074401855
# 403 4.026715278625488
# 404 11.865753173828125
# 405 3.9547784328460693
# 406 3.9381799697875977
# 407 4.556727886199951
# 408 4.1113200187683105
# 409 0.5656944513320923
# 410 4.345987319946289
# 411 2.1104655265808105
# 412 -0.13778585195541382
# 413 1.7648489475250244
# 414 -0.3383283317089081
# 415 2.723912000656128
# 416 6.026747703552246
# 417 3.247535228729248
# 418 4.8976216316223145
# 419 4.483492851257324
# 420 -1.6796034574508667
# 421 -0.4991489052772522
# 422 -0.6037912368774414
# 423 9.516555786132812
# 424 3.770455837249756
# 425 -2.5861384868621826
# 426 2.6978917121887207
# 427 -1.4055770635604858
# 428 1.0193989276885986
# 429 -1.4309945106506348
# 430 5.327650547027588
# 431 -0.3473696708679199
# 432 0.5645015239715576
# 433 -0.42559704184532166
# 434 9.888595581054688
# 435 6.056766510009766
# 436 6.7757720947265625
# 437 6.2449164390563965
# 438 0.1175374984741211
# 439 5.485346794128418
# 440 3.8903236389160156
# 441 9.36479377746582
# 442 1.387384057044983
# 443 7.378617763519287
# 444 3.210289239883423
# 445 3.7946059703826904
# 446 1.103611707687378
# 447 1.6207174062728882
# 448 -0.8246469497680664
# 449 -0.48037534952163696
# 450 -2.1683714389801025
# 451 6.394241809844971
# 452 -1.6988719701766968
# 453 -0.6215561032295227
# 454 4.736687660217285
# 455 2.080245018005371
# 456 2.212153434753418
# 457 2.0893638134002686
# 458 -3.4201090335845947
# 459 0.02698679268360138
# 460 6.973803520202637
# 461 12.341930389404297
# 462 2.783404588699341
# 463 0.5952668786048889
# 464 -1.4621334075927734
# 465 -2.6086556911468506
# 466 2.087322473526001
# 467 3.6577632427215576
# 468 1.6605908870697021
# 469 2.2272467613220215
# 470 4.26961612701416
# 471 2.526535749435425
# 472 -0.7032121419906616
# 473 -0.4433389902114868
# 474 4.713817119598389
# 475 -1.3469932079315186
# 476 12.571903228759766
# 477 7.147627830505371
# 478 5.305249214172363
# 479 3.1667640209198
# 480 -0.27250993251800537
# 481 0.4574006199836731
# 482 2.7474334239959717
# 483 11.423611640930176
# 484 1.3899197578430176
# 485 6.291884422302246
# 486 0.2349385768175125
# 487 6.226920127868652
# 488 -0.9509552717208862
# 489 1.3158085346221924
# 490 -0.3900980055332184
# 491 0.6939537525177002
# 492 5.03218936920166
# 493 -1.7601908445358276
# 494 0.2823432981967926
# 495 -2.2840583324432373
# 496 -1.7288265228271484
# 497 -0.8063706159591675
# 498 -0.11733502149581909
# 499 8.317971229553223
# 500 5.203956127166748
# 501 -1.3809806108474731
# 502 -0.055451810359954834
# 503 4.931919097900391
# 504 -1.1174414157867432
# 505 0.5018705129623413
# 506 -2.2247509956359863
# 507 0.0627671554684639
# 508 2.5678343772888184
# 509 1.3348630666732788
# 510 6.8300700187683105
# 511 -0.8974689841270447
# 512 3.5562708377838135
# 513 5.771208763122559
# 514 4.7392473220825195
# 515 2.023357391357422
# 516 6.710494518280029
# 517 4.109997749328613
# 518 0.15897047519683838
# 519 2.06026029586792
# 520 5.9540228843688965
# 521 0.2751638889312744
# 522 9.868597030639648
# 523 -0.8003334403038025
# 524 5.896138668060303
# 525 -1.508782148361206
# 526 1.6609934568405151
# 527 5.553589344024658
# 528 1.8854331970214844
# 529 6.137730598449707
# 530 1.3328425884246826
# 531 -2.932602643966675
# 532 3.0727992057800293
# 533 9.974960327148438
# 534 0.8445615768432617
# 535 7.580097675323486
# 536 0.577407956123352
# 537 -1.8262920379638672
# 538 4.140330791473389
# 539 -1.0590780973434448
# 540 8.071163177490234
# 541 3.0867042541503906
# 542 5.163324356079102
# 543 -3.307565927505493
# 544 -1.9810283184051514
# 545 2.9172327518463135
# 546 -2.3615550994873047
# 547 6.826723098754883
# 548 -0.47114256024360657
# 549 13.878218650817871
# 550 8.907981872558594
# 551 -1.5534769296646118
# 552 2.01606822013855
# 553 0.3135460615158081
# 554 0.705176591873169
# 555 8.382195472717285
# 556 0.0660235583782196
# 557 3.752971649169922
# 558 6.5611348152160645
# 559 2.8171193599700928
# 560 -2.4730913639068604
# 561 -0.5380874872207642
# 562 -0.7716994881629944
# 563 9.083892822265625
# 564 9.615508079528809
# 565 7.01865816116333
# 566 9.870113372802734
# 567 -0.03747677803039551
# 568 -1.680808663368225
# 569 4.571798324584961
# 570 10.597085952758789
# 571 11.846773147583008
# 572 4.466228485107422
# 573 1.44803786277771
# 574 1.5839482545852661
# 575 8.706618309020996
# 576 9.017229080200195
# 577 4.393472194671631
# 578 0.5022071599960327
# 579 1.9249107837677002
# 580 -0.7478273510932922
# 581 -0.14242370426654816
# 582 2.3241772651672363
# 583 2.9596705436706543
# 584 1.9106221199035645
# 585 4.42898416519165
# 586 2.206714391708374
# 587 6.199217796325684
# 588 0.32765281200408936
# 589 4.184325695037842
# 590 1.269801378250122
# 591 12.214293479919434
# 592 3.3027760982513428
# 593 -1.6585235595703125
# 594 4.496819496154785
# 595 -1.8061060905456543
# 596 1.82426118850708
# 597 2.7782375812530518
# 598 5.226038455963135
# 599 2.078920602798462
# 600 -1.1646182537078857
# 601 7.5935821533203125
# 602 1.9847848415374756
# 603 1.9323676824569702
# 604 6.062897682189941
# 605 3.335972547531128
# 606 3.941357374191284
# 607 -1.2129194736480713
# 608 9.352978706359863
# 609 6.742100715637207
# 610 1.16853928565979
# 611 -1.2856674194335938
# 612 0.1486516296863556
# 613 -0.9107481241226196
# 614 6.056728363037109
# 615 1.2535873651504517
# 616 -2.1959402561187744
# 617 3.5010135173797607
# 618 -2.315869092941284
# 619 0.621684730052948
# 620 -0.6065672636032104
# 621 1.5364617109298706
# 622 4.8774495124816895
# 623 -0.9073817133903503
# 624 3.5227396488189697
# 625 3.9993700981140137
# 626 -0.14203929901123047
# 627 -1.3983235359191895
# 628 5.113141059875488
# 629 -3.3937246799468994
# 630 0.775239884853363
# 631 2.7555036544799805
# 632 4.16926908493042
# 633 4.468153953552246
# 634 -0.38912487030029297
# 635 2.1387674808502197
# 636 2.7802741527557373
# 637 -1.6727451086044312
# 638 -1.833363652229309
# 639 2.3134546279907227
# 640 1.3054660558700562
# 641 0.6049514412879944
# 642 7.5812153816223145
# 643 0.39164844155311584
# 644 6.2082648277282715
# 645 0.3302006125450134
# 646 2.7769463062286377
# 647 -0.4037679433822632
# 648 0.7244614362716675
# 649 -1.4733266830444336
# 650 2.2322959899902344
# 651 6.5826802253723145
# 652 5.542978763580322
# 653 1.902883529663086
# 654 -2.4205031394958496
# 655 0.3885970115661621
# 656 4.7581987380981445
# 657 4.6272478103637695
# 658 -1.7387899160385132
# 659 -0.04690544307231903
# 660 2.7483742237091064
# 661 0.8876288533210754
# 662 6.237569332122803
# 663 6.942426681518555
# 664 -1.56172513961792
# 665 6.245039939880371
# 666 -1.5291717052459717
# 667 5.562191486358643
# 668 5.712386608123779
# 669 2.260389804840088
# 670 -1.4059522151947021
# 671 -0.2842974364757538
# 672 1.2038683891296387
# 673 2.3463215827941895
# 674 4.300441265106201
# 675 0.5396173596382141
# 676 8.06421184539795
# 677 7.55972957611084
# 678 8.433213233947754
# 679 -2.364518165588379
# 680 7.0653252601623535
# 681 5.179899215698242
# 682 2.6305437088012695
# 683 -0.900288462638855
# 684 4.607646465301514
# 685 -0.15699785947799683
# 686 7.43990421295166
# 687 -6.223668098449707
# 688 -0.5863768458366394
# 689 -1.5184228420257568
# 690 -0.27779942750930786
# 691 2.5844569206237793
# 692 0.8273207545280457
# 693 0.07935810089111328
# 694 -0.9893012046813965
# 695 8.576300621032715
# 696 3.291203737258911
# 697 9.172172546386719
# 698 3.0147080421447754
# 699 -0.5684288740158081
# 700 2.8048360347747803
# 701 -0.41196757555007935
# 702 0.04083371162414551
# 703 -2.9521594047546387
# 704 6.906301975250244
# 705 3.4109420776367188
# 706 0.48175331950187683
# 707 -0.6344557404518127
# 708 5.204254627227783
# 709 8.309945106506348
# 710 6.96646785736084
# 711 -0.20600862801074982
# 712 1.131577968597412
# 713 1.2875940799713135
# 714 1.9697810411453247
# 715 -0.7107217311859131
# 716 0.02944815158843994
# 717 -3.4048304557800293
# 718 0.48563262820243835
# 719 9.492319107055664
# 720 1.6402682065963745
# 721 7.470102310180664
# 722 10.056195259094238
# 723 3.380437135696411
# 724 0.4867101013660431
# 725 5.341490745544434
# 726 4.92529296875
# 727 -0.10279431939125061
# 728 -0.7918071150779724
# 729 -0.5830004811286926
# 730 4.916676998138428
# 731 -0.010772615671157837
# 732 9.475296974182129
# 733 9.784796714782715
# 734 2.078951597213745
# 735 1.4135853052139282
# 736 -1.3857529163360596
# 737 0.44954216480255127
# 738 1.0106836557388306
# 739 -0.3824557960033417
# 740 1.9558160305023193
# 741 -0.3538963496685028
# 742 -0.32690542936325073
# 743 5.086787700653076
# 744 3.6105198860168457
# 745 6.9103875160217285
# 746 -3.5157461166381836
# 747 0.1859017312526703
# 748 6.363122940063477
# 749 -1.1984325647354126
# 750 -0.9627441763877869
# 751 0.1650923192501068
# 752 -0.1824122667312622
# 753 7.235824108123779
# 754 0.4505714774131775
# 755 6.856088161468506
# 756 6.949985504150391
# 757 2.2253315448760986
# 758 12.620433807373047
# 759 1.2091548442840576
# 760 -0.10317997634410858
# 761 7.5721354484558105
# 762 6.266016483306885
# 763 8.155092239379883
# 764 0.6925135850906372
# 765 1.4471827745437622
# 766 -1.2711122035980225
# 767 7.093072891235352
# 768 3.9985921382904053
# 769 5.931341648101807
# 770 -3.755328893661499
# 771 4.866575241088867
# 772 4.32486629486084
# 773 6.607458591461182
# 774 9.179678916931152
# 775 -0.6145700216293335
# 776 9.591970443725586
# 777 2.0027902126312256
# 778 5.203436374664307
# 779 4.329654693603516
# 780 -0.16752883791923523
# 781 -1.0301767587661743
# 782 0.28319618105888367
# 783 4.313332557678223
# 784 8.107425689697266
# 785 7.756741046905518
# 786 5.268587112426758
# 787 0.7073430418968201
# 788 4.3388752937316895
# 789 -1.006454348564148
# 790 0.8368229866027832
# 791 3.103555917739868
# 792 7.780746936798096
# 793 1.9673964977264404
# 794 -1.6746443510055542
# 795 -0.18670371174812317
# 796 -0.633306622505188
# 797 -1.3712362051010132
# 798 8.863397598266602
# 799 -0.7731395959854126
# 800 8.221678733825684
# 801 -0.030992193147540092
# 802 1.8587384223937988
# 803 2.7528772354125977
# 804 5.963465690612793
# 805 -0.7786532640457153
# 806 1.8491065502166748
# 807 9.238848686218262
# 808 11.54047679901123
# 809 8.159796714782715
# 810 0.6723840236663818
# 811 -3.154801368713379
# 812 0.4822998642921448
# 813 -0.6169859170913696
# 814 -0.4760144352912903
# 815 4.033958911895752
# 816 -0.07710960507392883
# 817 3.5185389518737793
# 818 0.5009430050849915
# 819 1.1189019680023193
# 820 0.1258859783411026
# 821 1.1002860069274902
# 822 9.677299499511719
# 823 12.5968599319458
# 824 -0.6334293484687805
# 825 -0.1279773712158203
# 826 1.1143972873687744
# 827 1.9622408151626587
# 828 -0.5984354019165039
# 829 -0.9278272986412048
# 830 2.4629149436950684
# 831 0.9262888431549072
# 832 -2.0728871822357178
# 833 2.732050657272339
# 834 3.201514720916748
# 835 3.5549371242523193
# 836 -1.280004858970642
# 837 4.6727294921875
# 838 1.8043358325958252
# 839 10.7973051071167
# 840 4.416172027587891
# 841 0.5320460796356201
# 842 5.424624443054199
# 843 4.609654903411865
# 844 6.482895374298096
# 845 0.6079321503639221
# 846 -0.4930557906627655
# 847 -0.11223459243774414
# 848 -1.5047310590744019
# 849 7.13865852355957
# 850 -2.894636631011963
# 851 0.1825789511203766
# 852 0.025867179036140442
# 853 -1.3053467273712158
# 854 2.9269073009490967
# 855 4.228327751159668
# 856 -1.1434370279312134
# 857 -1.390249252319336
# 858 0.9506217837333679
# 859 3.934133291244507
# 860 3.149916172027588
# 861 -1.4261467456817627
# 862 -5.216448783874512
# 863 1.5700938701629639
# 864 5.014674186706543
# 865 2.4603946208953857
# 866 -1.6755269765853882
# 867 -0.6497092247009277
# 868 -0.4507509171962738
# 869 3.9616751670837402
# 870 -0.1537717878818512
# 871 8.374311447143555
# 872 3.0011773109436035
# 873 -1.3021599054336548
# 874 7.006939888000488
# 875 -0.13057157397270203
# 876 0.21347913146018982
# 877 9.081124305725098
# 878 1.2372169494628906
# 879 0.18142113089561462
# 880 5.061752796173096
# 881 1.1022876501083374
# 882 9.138731956481934
# 883 2.636570692062378
# 884 6.243093013763428
# 885 2.1858153343200684
# 886 2.15535569190979
# 887 1.6927385330200195
# 888 1.0501577854156494
# 889 2.4969868659973145
# 890 0.9087052345275879
# 891 -0.8302268385887146
# 892 -0.26766350865364075
# 893 1.3232548236846924
# 894 9.758438110351562
# 895 1.7153489589691162
# 896 3.29166316986084
# 897 3.2465620040893555
# 898 3.5825412273406982
# 899 -1.5627920627593994
# 900 -0.3303147852420807
# 901 5.2175374031066895
# 902 5.367923736572266
# 903 5.295049667358398
# 904 0.9338939189910889
# 905 -0.547459065914154
# 906 4.309864521026611
# 907 8.196414947509766
# 908 4.699783802032471
# 909 -0.6139674782752991
# 910 -0.5571041703224182
# 911 1.1250585317611694
# 912 0.712410569190979
# 913 2.921086549758911
# 914 1.8693889379501343
# 915 3.508319616317749
# 916 0.999938428401947
# 917 1.2111378908157349
# 918 1.520573616027832
# 919 9.584885597229004
# 920 -4.262629508972168
# 921 3.286499261856079
# 922 0.28424882888793945
# 923 0.03744255006313324
# 924 -1.0158967971801758
# 925 5.426319599151611
# 926 7.180536270141602
# 927 6.1526360511779785
# 928 3.8253931999206543
# 929 -3.346827983856201
# 930 -0.710973858833313
# 931 2.787513017654419
# 932 -1.2439063787460327
# 933 -3.928335189819336
# 934 9.05670166015625
# 935 -0.259535551071167
# 936 3.0621047019958496
# 937 -0.3968777656555176
# 938 -1.765985131263733
# 939 0.30267518758773804
# 940 -1.2195112705230713
# 941 -1.9817466735839844
# 942 1.9030160903930664
# 943 1.5582927465438843
# 944 2.3655874729156494
# 945 0.17565099895000458
# 946 -0.36494433879852295
# 947 -1.954892635345459
# 948 2.3583855628967285
# 949 -1.9372318983078003
# 950 3.87477970123291
# 951 2.3755688667297363
# 952 4.036245346069336
# 953 8.494826316833496
# 954 1.4586598873138428
# 955 3.8027613162994385
# 956 -1.6315730810165405
# 957 -1.479623794555664
# 958 1.5988290309906006
# 959 1.163411259651184
# 960 4.318164825439453
# 961 -0.1370122730731964
# 962 0.7091206312179565
# 963 1.5751583576202393
# 964 -1.0673059225082397
# 965 7.431640148162842
# 966 13.729682922363281
# 967 -0.15208083391189575
# 968 1.68234121799469
# 969 0.23585927486419678
# 970 8.730609893798828
# 971 -0.41222530603408813
# 972 3.1732382774353027
# 973 2.506898880004883
# 974 -4.427277088165283
# 975 -1.1526930332183838
# 976 0.24418598413467407
# 977 3.386331081390381
# 978 0.7629029750823975
# 979 4.416300296783447
# 980 -0.12863609194755554
# 981 10.323019981384277
# 982 4.362173080444336
# 983 -0.1083100438117981
# 984 0.7826666235923767
# 985 -0.11885405331850052
# 986 7.1069416999816895
# 987 -1.2259658575057983
# 988 -3.8717949390411377
# 989 -0.2168482095003128
# 990 6.435336589813232
# 991 7.730594158172607
# 992 -0.7931230068206787
# 993 -2.8007709980010986
# 994 8.706074714660645
# 995 -1.995975375175476
# 996 10.527470588684082
# 997 3.739464044570923
# 998 7.746775150299072
# 999 2.6946020126342773
# 1000 4.208340644836426
# 1001 1.6756798028945923
# 1002 3.5056190490722656
# 1003 -1.2408297061920166
# 1004 3.668379783630371
# 1005 2.218215227127075
# 1006 -2.947542190551758
# 1007 0.971611499786377
# 1008 11.870109558105469
# 1009 -0.9579388499259949
# 1010 5.487194061279297
# 1011 7.225032806396484
# 1012 6.1626434326171875
# 1013 0.6933284401893616
# 1014 2.968073844909668
# 1015 -1.460545539855957
# 1016 3.0966978073120117
# 1017 -0.8109126687049866
# 1018 3.099153757095337
# 1019 1.0314710140228271
# 1020 2.0589816570281982
# 1021 6.477231025695801
# 1022 0.30066201090812683
# 1023 1.6036734580993652
# 1024 3.734070301055908
# 1025 -0.7362792491912842
# 1026 0.29334086179733276
# 1027 -0.9851380586624146
# 1028 3.1425864696502686
# 1029 0.2746656537055969
# 1030 1.9696016311645508
# 1031 7.2315897941589355
# 1032 0.6337777972221375
# 1033 5.283689498901367
# 1034 3.9146134853363037
# 1035 7.085512161254883
# 1036 3.219693660736084
# 1037 -2.2719202041625977
# 1038 -1.1472758054733276
# 1039 4.17287540435791
# 1040 1.891080379486084
# 1041 3.8030505180358887
# 1042 10.949084281921387
# 1043 2.508408308029175
# 1044 5.077861785888672
# 1045 -0.3800123333930969
# 1046 -1.9724897146224976
# 1047 4.557020664215088
# 1048 3.3568618297576904
# 1049 3.053757667541504
# 1050 0.8450478315353394
# 1051 -1.4184415340423584
# 1052 6.787582874298096
# 1053 4.472131729125977
# 1054 0.6301851868629456
# 1055 3.0321168899536133
# 1056 6.024994850158691
# 1057 -0.7047020196914673
# 1058 -2.0826900005340576
# 1059 3.490635395050049
# 1060 1.6612731218338013
# 1061 5.452895164489746
# 1062 8.676703453063965
# 1063 -0.04351247847080231
# 1064 -0.10987520217895508
# 1065 -0.31439751386642456
# 1066 -0.7708922624588013
# 1067 6.511673450469971
# 1068 -0.8937698602676392
# 1069 -2.2039639949798584
# 1070 -2.5380566120147705
# 1071 -0.7248759865760803
# 1072 1.1906318664550781
# 1073 2.974921464920044
# 1074 2.782036066055298
# 1075 0.48546290397644043
# 1076 0.7237327098846436
# 1077 -0.6842482089996338
# 1078 4.479933261871338
# 1079 8.303024291992188
# 1080 2.8843576908111572
# 1081 -0.9354249238967896
# 1082 2.2539150714874268
# 1083 3.473419189453125
# 1084 5.593471527099609
# 1085 3.245555877685547
# 1086 5.622360706329346
# 1087 2.439619302749634
# 1088 11.02755069732666
# 1089 2.300327777862549
# 1090 -0.5068743228912354
# 1091 4.511868000030518
# 1092 -1.4672458171844482
# 1093 6.691851615905762
# 1094 5.825026035308838
# 1095 8.233250617980957
# 1096 -1.1123723983764648
# 1097 5.404772758483887
# 1098 -2.37734055519104
# 1099 2.040515661239624
# 1100 4.7870941162109375
# 1101 2.9837543964385986
# 1102 -1.1948336362838745
# 1103 -1.2930984497070312
# 1104 9.411017417907715
# 1105 -0.014827370643615723
# 1106 -1.0000858306884766
# 1107 5.268625259399414
# 1108 -0.7299740314483643
# 1109 2.3151426315307617
# 1110 1.0059442520141602
# 1111 10.21612548828125
# 1112 3.249405860900879
# 1113 8.1640043258667
# 1114 3.650949478149414
# 1115 -0.5585357546806335
# 1116 -1.375265121459961
# 1117 11.11123275756836
# 1118 -2.819155693054199
# 1119 4.524735927581787
# 1120 6.6311187744140625
# 1121 2.8304193019866943
# 1122 0.34761565923690796
# 1123 4.590191841125488
# 1124 -0.7155197858810425
# 1125 3.203974962234497
# 1126 1.2662042379379272
# 1127 -0.5001940727233887
# 1128 -1.0389516353607178
# 1129 -0.20362794399261475
# 1130 3.706829786300659
# 1131 -2.3996479511260986
# 1132 8.402585983276367
# 1133 2.1725690364837646
# 1134 8.972890853881836
# 1135 4.629760265350342
# 1136 3.8553638458251953
# 1137 -0.04449760913848877
# 1138 0.019715189933776855
# 1139 -0.5133915543556213
# 1140 6.213059425354004
# 1141 6.809865474700928
# 1142 -0.41744881868362427
# 1143 -0.151560440659523
# 1144 -0.7403749227523804
# 1145 -0.07366973161697388
# 1146 -1.6755963563919067
# 1147 2.653860092163086
# 1148 7.415691375732422
# 1149 1.5958095788955688
# 1150 1.344321370124817
# 1151 4.4223809242248535
# 1152 -2.5761220455169678
# 1153 6.073022365570068
# 1154 3.419881582260132
# 1155 0.40688300132751465
# 1156 -1.1585469245910645
# 1157 0.3026096224784851
# 1158 0.09437721967697144
# 1159 -1.2861428260803223
# 1160 2.302417516708374
# 1161 0.5851606130599976
# 1162 -1.961719274520874
# 1163 0.7025363445281982
# 1164 3.3046247959136963
# 1165 1.0250194072723389
# 1166 -0.35450467467308044
# 1167 0.5750939846038818
# 1168 0.07916945219039917
# 1169 0.6124905347824097
# 1170 3.5589640140533447
# 1171 2.0262904167175293
# 1172 0.29996997117996216
# 1173 9.122631072998047
# 1174 6.023552894592285
# 1175 5.86480188369751
# 1176 1.3359277248382568
# 1177 4.508690357208252
# 1178 -0.3343908190727234
# 1179 2.599792718887329
# 1180 0.8363803029060364
# 1181 0.6993514895439148
# 1182 3.6810245513916016
# 1183 0.6658254265785217
# 1184 1.289154291152954
# 1185 -0.32949888706207275
# 1186 -1.314355731010437
# 1187 3.3542568683624268
# 1188 4.636474132537842
# 1189 3.9415042400360107
# 1190 -2.6249642372131348
# 1191 7.499979496002197
# 1192 0.21114549040794373
# 1193 0.8322470784187317
# 1194 11.285526275634766
# 1195 4.4763078689575195
# 1196 6.472803592681885
# 1197 -2.0326218605041504
# 1198 0.308653324842453
# 1199 4.982174396514893
# 1200 5.51837158203125
# 1201 -2.427701711654663
# 1202 3.1159121990203857
# 1203 2.246098279953003
# 1204 3.291461229324341
# 1205 5.749638080596924
# 1206 1.107568383216858
# 1207 0.7131969332695007
# 1208 1.7506918907165527
# 1209 0.7810848951339722
# 1210 2.2023258209228516
# 1211 -1.2755019664764404
# 1212 -1.6617916822433472
# 1213 1.5853301286697388
# 1214 -2.658832311630249
# 1215 0.29654961824417114
# 1216 9.461983680725098
# 1217 2.6872406005859375
# 1218 -1.2832727432250977
# 1219 1.9511258602142334
# 1220 1.1834344863891602
# 1221 0.7760118246078491
# 1222 3.692890167236328
# 1223 -3.0310068130493164
# 1224 1.7348006963729858
# 1225 0.24880866706371307
# 1226 7.605668544769287
# 1227 -1.0000905990600586
# 1228 6.64108943939209
# 1229 6.596419811248779
# 1230 2.340987205505371
# 1231 -1.9596554040908813
# 1232 0.672568142414093
# 1233 1.1542948484420776
# 1234 -3.2218899726867676
# 1235 -1.2941845655441284
# 1236 8.338685035705566
# 1237 -0.14457236230373383
# 1238 8.744799613952637
# 1239 -0.05165639519691467
# 1240 -1.7422934770584106
# 1241 3.499314069747925
# 1242 0.7344492077827454
# 1243 1.4040708541870117
# 1244 -2.3898675441741943
# 1245 1.9471293687820435
# 1246 3.1377484798431396
# 1247 -1.299887776374817
# 1248 4.2086052894592285
# 1249 3.779817581176758
# 1250 5.55967378616333
# 1251 -2.387634038925171
# 1252 3.2292869091033936
# 1253 8.109941482543945
# 1254 8.564544677734375
# 1255 6.141979694366455
# 1256 -0.9663510322570801
# 1257 8.958847045898438
# 1258 -1.7370097637176514
# 1259 13.534723281860352
# 1260 4.5319414138793945
# 1261 4.099837779998779
# 1262 1.63975191116333
# 1263 1.6011534929275513
# 1264 -1.1094439029693604
# 1265 0.04977981746196747
# 1266 1.717927098274231
# 1267 -1.992640733718872
# 1268 0.5988290905952454
# 1269 12.13812255859375
# 1270 8.372130393981934
# 1271 -2.8444695472717285
# 1272 9.463074684143066
# 1273 -0.2098369002342224
# 1274 0.48034411668777466
# 1275 -1.0986406803131104
# 1276 16.999122619628906
# 1277 0.7381612658500671
# 1278 -4.0539021492004395
# 1279 -0.976862907409668
# 1280 -0.5667701959609985
# 1281 2.1463842391967773
# 1282 1.6600013971328735
# 1283 -0.38105595111846924
# 1284 3.3645763397216797
# 1285 -0.5845591425895691
# 1286 11.623071670532227
# 1287 0.40456926822662354
# 1288 5.784846782684326
# 1289 -0.40560346841812134
# 1290 -1.902597188949585
# 1291 3.588493585586548
# 1292 4.192157745361328
# 1293 1.4985034465789795
# 1294 5.732882499694824
# 1295 10.36242389678955
# 1296 7.189248561859131
# 1297 12.953629493713379
# 1298 -0.6617794036865234
# 1299 2.2829251289367676
# 1300 0.7818489074707031
# 1301 7.956299781799316
# 1302 0.008644640445709229
# 1303 5.2285637855529785
# 1304 1.4137611389160156
# 1305 7.724072456359863
# 1306 -0.41129276156425476
# 1307 -0.518022894859314
# 1308 -0.40270474553108215
# 1309 -0.2896289527416229
# 1310 0.806045413017273
# 1311 4.536016464233398
# 1312 -1.0569995641708374
# 1313 -1.756976842880249
# 1314 3.1702587604522705
# 1315 8.979581832885742
# 1316 -0.0175473652780056
# 1317 1.4399031400680542
# 1318 5.931097507476807
# 1319 3.2120614051818848
# 1320 4.475611686706543
# 1321 2.2464210987091064
# 1322 0.9270958304405212
# 1323 0.22060132026672363
# 1324 4.018491744995117
# 1325 -0.7524902820587158
# 1326 -0.616685152053833
# 1327 -0.21496132016181946
# 1328 -1.1283676624298096
# 1329 2.3767879009246826
# 1330 -2.7455146312713623
# 1331 -0.6466626524925232
# 1332 1.3957511186599731
# 1333 5.667166233062744
# 1334 -0.1561405509710312
# 1335 0.325472891330719
# 1336 1.126607060432434
# 1337 1.9352010488510132
# 1338 5.2263641357421875
# 1339 8.469176292419434
# 1340 5.701854228973389
# 1341 1.4812532663345337
# 1342 12.736336708068848
# 1343 3.2542436122894287
# 1344 7.884122848510742
# 1345 -1.0344445705413818
# 1346 0.6368324756622314
# 1347 0.18416446447372437
# 1348 0.08302919566631317
# 1349 -0.9195280075073242
# 1350 5.65920877456665
# 1351 -0.4291204810142517
# 1352 5.953189373016357
# 1353 5.869213581085205
# 1354 1.0033528804779053
# 1355 4.497347354888916
# 1356 7.14446496963501
# 1357 9.408682823181152
# 1358 -1.1950633525848389
# 1359 2.2717108726501465
# 1360 -2.3850414752960205
# 1361 3.440858840942383
# 1362 -1.7636317014694214
# 1363 -1.169025182723999
# 1364 5.7598981857299805
# 1365 2.0687339305877686
# 1366 7.356435298919678
# 1367 -1.552609920501709
# 1368 1.784353256225586
# 1369 6.390590190887451
# 1370 4.18088436126709
# 1371 2.9814960956573486
# 1372 -1.8250150680541992
# 1373 7.7613091468811035
# 1374 -0.8163554072380066
# 1375 5.814367294311523
# 1376 2.9578447341918945
# 1377 4.667173385620117
# 1378 7.172476768493652
# 1379 0.9995913505554199
# 1380 -0.5781508684158325
# 1381 5.373447895050049
# 1382 1.633941888809204
# 1383 -0.3367409110069275
# 1384 5.524549961090088
# 1385 1.6850214004516602
# 1386 -1.9630513191223145
# 1387 3.992565393447876
# 1388 5.379828453063965
# 1389 -0.3837580680847168
# 1390 9.003267288208008
# 1391 -2.466815948486328
# 1392 3.108884334564209
# 1393 3.0424137115478516
# 1394 0.304715096950531
# 1395 5.087309837341309
# 1396 2.656747341156006
# 1397 -2.7128639221191406
# 1398 3.394028425216675
# 1399 5.555030822753906
# 1400 6.405112266540527
# 1401 3.0153188705444336
# 1402 9.545816421508789
# 1403 7.564329147338867
# 1404 0.8746559619903564
# 1405 2.7563178539276123
# 1406 1.0217310190200806
# 1407 3.168301582336426
# 1408 -1.0304584503173828
# 1409 2.385683059692383
# 1410 -1.3857189416885376
# 1411 2.160168409347534
# 1412 6.124691963195801
# 1413 4.0542473793029785
# 1414 2.3485491275787354
# 1415 7.9839277267456055
# 1416 0.13835802674293518
# 1417 -0.7803277969360352
# 1418 -0.32485464215278625
# 1419 -0.19331419467926025
# 1420 1.039370059967041
# 1421 2.3566455841064453
# 1422 4.114992618560791
# 1423 -0.712060809135437
# 1424 4.006714344024658
# 1425 1.2171928882598877
# 1426 9.863751411437988
# 1427 -0.7136421203613281
# 1428 3.698957920074463
# 1429 -0.16321660578250885
# 1430 0.4374195337295532
# 1431 2.552630662918091
# 1432 2.305058479309082
# 1433 -1.4595046043395996
# 1434 2.7258691787719727
# 1435 3.4962611198425293
# 1436 8.31621265411377
# 1437 -0.9999993443489075
# 1438 -0.42183804512023926
# 1439 0.4772101938724518
# 1440 9.722114562988281
# 1441 1.124510645866394
# 1442 5.587735652923584
# 1443 7.781404495239258
# 1444 -0.5789431929588318
# 1445 6.913375377655029
# 1446 -1.151049256324768
# 1447 3.3724863529205322
# 1448 3.497727155685425
# 1449 -0.1623152494430542
# 1450 -1.240896224975586
# 1451 -0.40982842445373535
# 1452 5.1087117195129395
# 1453 4.336297512054443
# 1454 1.2444887161254883
# 1455 8.474701881408691
# 1456 1.4065431356430054
# 1457 0.43902960419654846
# 1458 3.9324800968170166
# 1459 1.5382097959518433
# 1460 7.81145715713501
# 1461 4.702559947967529
# 1462 5.922314167022705
# 1463 7.133902072906494
# 1464 3.4566245079040527
# 1465 1.7051125764846802
# 1466 3.1123223304748535
# 1467 5.79562520980835
# 1468 2.660709857940674
# 1469 5.406473159790039
# 1470 -0.9089846611022949
# 1471 0.0634070634841919
# 1472 6.292967319488525
# 1473 6.342928409576416
# 1474 0.2785562574863434
# 1475 0.9471633434295654
# 1476 4.589446544647217
# 1477 0.9682336449623108
# 1478 -0.3658705949783325
# 1479 3.3750860691070557
# 1480 3.6630280017852783
# 1481 -1.6473885774612427
# 1482 13.096458435058594
# 1483 2.9258053302764893
# 1484 2.2455499172210693
# 1485 1.1150318384170532
# 1486 3.4365508556365967
# 1487 -0.7344434261322021
# 1488 -2.289090156555176
# 1489 4.844988822937012
# 1490 0.7526877522468567
# 1491 -1.243760108947754
# 1492 1.5618637800216675
# 1493 0.4262574315071106
# 1494 11.367191314697266
# 1495 3.7792766094207764
# 1496 7.8691020011901855
# 1497 8.955390930175781
# 1498 2.1509125232696533
# 1499 1.8656824827194214
# 1500 10.983013153076172
# 1501 -0.05740821361541748
# 1502 -0.3667721152305603
# 1503 5.7690653800964355
# 1504 1.8578159809112549
# 1505 3.251422882080078
# 1506 2.9172279834747314
# 1507 -3.7228593826293945
# 1508 9.270532608032227
# 1509 1.2164666652679443
# 1510 0.2910849452018738
# 1511 0.27856558561325073
# 1512 8.431465148925781
# 1513 7.191981315612793
# 1514 -1.8872820138931274
# 1515 3.5564072132110596
# 1516 5.863412857055664
# 1517 1.2391667366027832
# 1518 -1.6909760236740112
# 1519 5.773425102233887
# 1520 0.8909101486206055
# 1521 6.651248931884766
# 1522 1.0585198402404785
# 1523 -2.743492364883423
# 1524 2.256298303604126
# 1525 -0.827542781829834
# 1526 -0.1330346167087555
# 1527 -2.793459415435791
# 1528 0.4315716624259949
# 1529 1.2866277694702148
# 1530 -2.2658286094665527
# 1531 0.29647547006607056
# 1532 4.0916900634765625
# 1533 -0.41706860065460205
# 1534 1.828371286392212
# 1535 -3.7547528743743896
# 1536 8.960809707641602
# 1537 8.992549896240234
# 1538 -1.3131383657455444
# 1539 5.967419624328613
# 1540 6.6283159255981445
# 1541 4.597857475280762
# 1542 5.641757965087891
# 1543 -0.357923686504364
# 1544 3.327610969543457
# 1545 9.450078010559082
# 1546 0.6995410919189453
# 1547 9.694039344787598
# 1548 -0.03267231211066246
# 1549 1.3852472305297852
# 1550 10.684974670410156
# 1551 2.5879461765289307
# 1552 0.5345907211303711
# 1553 2.583125114440918
# 1554 2.942870855331421
# 1555 -1.8153667449951172
# 1556 -3.276669979095459
# 1557 -0.3250647187232971
# 1558 9.955047607421875
# 1559 8.008337020874023
# 1560 7.931365966796875
# 1561 2.2121925354003906
# 1562 9.40253734588623
# 1563 8.817366600036621
# 1564 0.6123393774032593
# 1565 8.419831275939941
# 1566 4.609574317932129
# 1567 11.594060897827148
# 1568 -1.0037988424301147
# 1569 1.7281038761138916
# 1570 -2.179596424102783
# 1571 2.2112135887145996
# 1572 -1.0419118404388428
# 1573 -0.6301836371421814
# 1574 -0.2000482976436615
# 1575 8.882345199584961
# 1576 1.2502732276916504
# 1577 6.586738586425781
# 1578 -2.6716630458831787
# 1579 4.546570301055908
# 1580 1.365867257118225
# 1581 0.7140356302261353
# 1582 7.04312801361084
# 1583 0.2672145962715149
# 1584 -2.162585496902466
# 1585 -2.9614219665527344
# 1586 2.661078929901123
# 1587 2.427403688430786
# 1588 0.8647497892379761
# 1589 0.8887452483177185
# 1590 2.228919267654419
# 1591 6.716892719268799
# 1592 -1.1008459329605103
# 1593 9.462897300720215
# 1594 5.452699661254883
# 1595 2.392956256866455
# 1596 -1.240982174873352
# 1597 -1.3304277658462524
# 1598 8.20057487487793
# 1599 2.767803907394409
# 1600 0.2200774997472763
# 1601 -4.296222686767578
# 1602 -1.6052088737487793
# 1603 -0.16636337339878082
# 1604 0.19476217031478882
# 1605 8.152482032775879
# 1606 3.376176118850708
# 1607 0.3269721567630768
# 1608 2.4013288021087646
# 1609 -0.9160975813865662
# 1610 1.4058423042297363
# 1611 -0.6521327495574951
# 1612 5.610203742980957
# 1613 3.6581778526306152
# 1614 -0.9903333187103271
# 1615 -1.2945520877838135
# 1616 3.301652431488037
# 1617 -1.5098410844802856
# 1618 8.334887504577637
# 1619 1.7060593366622925
# 1620 7.713348865509033
# 1621 -1.4365944862365723
# 1622 8.185834884643555
# 1623 -1.544334888458252
# 1624 0.9811922311782837
# 1625 2.983119249343872
# 1626 -0.12089071422815323
# 1627 6.392749786376953
# 1628 5.117746829986572
# 1629 1.1981139183044434
# 1630 3.0702242851257324
# 1631 0.038713496178388596
# 1632 5.190584659576416
# 1633 -0.8907148838043213
# 1634 0.8857235312461853
# 1635 3.9903414249420166
# 1636 -2.0361504554748535
# 1637 0.08558063954114914
# 1638 0.6259836554527283
# 1639 -3.354360580444336
# 1640 -0.10425661504268646
# 1641 1.7536983489990234
# 1642 -0.3232642710208893
# 1643 4.451880931854248
# 1644 -2.1534605026245117
# 1645 0.28523585200309753
# 1646 7.268317222595215
# 1647 3.1383538246154785
# 1648 -0.855259895324707
# 1649 5.542710304260254
# 1650 -1.1930993795394897
# 1651 3.898874521255493
# 1652 8.846739768981934
# 1653 3.3419809341430664
# 1654 -1.311570405960083
# 1655 4.042017936706543
# 1656 8.54590129852295
# 1657 0.30482882261276245
# 1658 -1.9059169292449951
# 1659 -0.7066328525543213
# 1660 1.480324625968933
# 1661 4.245744228363037
# 1662 3.4592437744140625
# 1663 0.16788068413734436
# 1664 12.406617164611816
# 1665 1.241476058959961
# 1666 -1.9121637344360352
# 1667 1.786346435546875
# 1668 1.2415132522583008
# 1669 3.9025774002075195
# 1670 7.343538284301758
# 1671 11.085196495056152
# 1672 1.299185872077942
# 1673 3.3672404289245605
# 1674 -0.3181723654270172
# 1675 0.22942450642585754
# 1676 3.0090973377227783
# 1677 7.182173728942871
# 1678 0.06409959495067596
# 1679 0.4274466037750244
# 1680 4.341119766235352
# 1681 2.9835658073425293
# 1682 3.2677643299102783
# 1683 0.3455597758293152
# 1684 -0.1028319001197815
# 1685 5.747065544128418
# 1686 -2.8925983905792236
# 1687 -0.0022279024124145508
# 1688 4.862976551055908
# 1689 11.15363597869873
# 1690 -2.2805137634277344
# 1691 4.2387495040893555
# 1692 -1.4252926111221313
# 1693 0.564143180847168
# 1694 1.9387685060501099
# 1695 1.4118115901947021
# 1696 1.3929153680801392
# 1697 0.27129727602005005
# 1698 -1.8611420392990112
# 1699 -1.6575806140899658
# 1700 3.8771181106567383
# 1701 -1.355057954788208
# 1702 1.0685737133026123
# 1703 -0.05249601602554321
# 1704 2.564795970916748
# 1705 -0.5342367887496948
# 1706 -1.5049986839294434
# 1707 5.0228705406188965
# 1708 8.00042724609375
# 1709 3.662473440170288
# 1710 2.786168336868286
# 1711 0.7338549494743347
# 1712 -1.268878698348999
# 1713 -0.41965872049331665
# 1714 4.573760509490967
# 1715 0.9155068397521973
# 1716 4.089740753173828
# 1717 3.1073544025421143
# 1718 0.04590124636888504
# 1719 10.817604064941406
# 1720 3.822504997253418
# 1721 1.0712127685546875
# 1722 -1.6716537475585938
# 1723 8.325911521911621
# 1724 1.9788590669631958
# 1725 0.961260199546814
# 1726 1.253913164138794
# 1727 5.4379425048828125
# 1728 0.9387906789779663
# 1729 -0.25217512249946594
# 1730 5.027978420257568
# 1731 6.411319732666016
# 1732 2.0731124877929688
# 1733 1.0118757486343384
# 1734 -2.1947896480560303
# 1735 2.4180233478546143
# 1736 10.097671508789062
# 1737 2.487527847290039
# 1738 1.8495303392410278
# 1739 5.541700839996338
# 1740 1.8386226892471313
# 1741 3.212595224380493
# 1742 10.801566123962402
# 1743 -0.9051470160484314
# 1744 -2.0927574634552
# 1745 8.213288307189941
# 1746 2.9270119667053223
# 1747 1.1995313167572021
# 1748 2.8360965251922607
# 1749 0.8401203155517578
# 1750 7.815834045410156
# 1751 -1.5012738704681396
# 1752 -1.6324480772018433
# 1753 3.9402549266815186
# 1754 6.5560150146484375
# 1755 0.10567815601825714
# 1756 2.631147623062134
# 1757 7.862000465393066
# 1758 4.567460536956787
# 1759 -3.07053804397583
# 1760 5.62176513671875
# 1761 2.8986010551452637
# 1762 0.21977639198303223
# 1763 0.09008371829986572
# 1764 10.631255149841309
# 1765 0.43833133578300476
# 1766 4.147205352783203
# 1767 4.5096940994262695
# 1768 2.397508144378662
# 1769 10.257862091064453
# 1770 1.255995273590088
# 1771 0.987385094165802
# 1772 -2.710080146789551
# 1773 3.306792736053467
# 1774 12.349538803100586
# 1775 3.946228504180908
# 1776 3.7895917892456055
# 1777 4.584858417510986
# 1778 2.527935266494751
# 1779 2.086456060409546
# 1780 1.340060830116272
# 1781 0.3474329113960266
# 1782 2.410364866256714
# 1783 -2.1333811283111572
# 1784 2.824568748474121
# 1785 0.45500996708869934
# 1786 1.7420244216918945
# 1787 9.134389877319336
# 1788 0.49092841148376465
# 1789 -1.2910388708114624
# 1790 3.845156192779541
# 1791 8.413314819335938
# 1792 3.9743735790252686
# 1793 0.56303870677948
# 1794 5.4872212409973145
# 1795 3.5482921600341797
# 1796 0.8834192752838135
# 1797 3.1506340503692627
# 1798 1.563960075378418
# 1799 -1.9829682111740112
# 1800 -1.0278208255767822
# 1801 1.775923490524292
# 1802 5.673639297485352
# 1803 6.533891677856445
# 1804 4.03563117980957
# 1805 0.00290788896381855
# 1806 -2.218996047973633
# 1807 3.4401867389678955
# 1808 7.587081432342529
# 1809 3.375047206878662
# 1810 -0.8579801321029663
# 1811 4.629894256591797
# 1812 2.054386854171753
# 1813 -0.1500035524368286
# 1814 -1.2069729566574097
# 1815 4.240816593170166
# 1816 -1.8054823875427246
# 1817 9.334922790527344
# 1818 0.4354829788208008
# 1819 9.013066291809082
# 1820 -3.154181480407715
# 1821 0.5883511900901794
# 1822 -0.4289873540401459
# 1823 6.406598091125488
# 1824 -1.7767152786254883
# 1825 -0.7147813439369202
# 1826 6.065277099609375
# 1827 -7.3353095054626465
# 1828 1.1306273937225342
# 1829 0.5534549951553345
# 1830 0.7894275784492493
# 1831 4.0108723640441895
# 1832 -0.9437766075134277
# 1833 -2.07539963722229
# 1834 2.793198585510254
# 1835 -2.379598379135132
# 1836 -0.3183911442756653
# 1837 -2.963564157485962
# 1838 2.817859172821045
# 1839 0.3296380937099457
# 1840 3.457223892211914
# 1841 1.2747573852539062
# 1842 -1.4784154891967773
# 1843 2.885721445083618
# 1844 9.092796325683594
# 1845 4.029558181762695
# 1846 4.283506393432617
# 1847 5.486432075500488
# 1848 4.985738754272461
# 1849 0.6973484754562378
# 1850 1.4119811058044434
# 1851 3.603771686553955
# 1852 7.135790824890137
# 1853 1.5991113185882568
# 1854 0.5795061588287354
# 1855 9.36716365814209
# 1856 2.845369577407837
# 1857 4.589031219482422
# 1858 4.073550224304199
# 1859 -0.9778809547424316
# 1860 -0.1212003156542778
# 1861 1.2148268222808838
# 1862 -2.378040313720703
# 1863 -1.7799232006072998
# 1864 2.6860604286193848
# 1865 -0.35421374440193176
# 1866 -1.6620347499847412
# 1867 5.102606773376465
# 1868 3.3739538192749023
# 1869 0.8105629086494446
# 1870 9.7746000289917
# 1871 0.9877367615699768
# 1872 2.2293105125427246
# 1873 8.15713882446289
# 1874 4.602723121643066
# 1875 -0.46445512771606445
# 1876 1.0020886659622192
# 1877 7.2309250831604
# 1878 1.7428311109542847
# 1879 5.86497163772583
# 1880 0.19863015413284302
# 1881 -0.09559109807014465
# 1882 -1.716414451599121
# 1883 7.093898296356201
# 1884 -0.8921740055084229
# 1885 -1.150719165802002
# 1886 3.827699899673462
# 1887 2.1920924186706543
# 1888 1.8559849262237549
# 1889 6.754093170166016
# 1890 2.152066230773926
# 1891 -1.964187502861023
# 1892 0.43026554584503174
# 1893 0.6297019720077515
# 1894 2.822852611541748
# 1895 1.372304081916809
# 1896 1.746556282043457
# 1897 1.0156224966049194
# 1898 0.4959236681461334
# 1899 4.163037300109863
# 1900 0.44844216108322144
# 1901 0.8521608710289001
# 1902 -0.8374784588813782
# 1903 -1.0527266263961792
# 1904 -0.7464755177497864
# 1905 2.775128126144409
# 1906 3.699700355529785
# 1907 -1.0310897827148438
# 1908 -1.1614909172058105
# 1909 1.6078002452850342
# 1910 2.905277967453003
# 1911 -0.40546536445617676
# 1912 0.5033166408538818
# 1913 -0.2774752378463745
# 1914 2.4021928310394287
# 1915 1.331339716911316
# 1916 1.688152551651001
# 1917 9.85693645477295
# 1918 11.12264633178711
# 1919 4.27296257019043
# 1920 0.08048251271247864
# 1921 2.8858330249786377
# 1922 3.9085655212402344
# 1923 -4.184473514556885
# 1924 -1.2032448053359985
# 1925 -0.9044189453125
# 1926 -2.6727845668792725
# 1927 -3.946964740753174
# 1928 -1.634459376335144
# 1929 9.948847770690918
# 1930 5.773658275604248
# 1931 -2.6097164154052734
# 1932 -0.5045937895774841
# 1933 4.695249557495117
# 1934 -1.0583906173706055
# 1935 5.879930019378662
# 1936 8.044380187988281
# 1937 -0.15733927488327026
# 1938 -1.016343593597412
# 1939 7.179599285125732
# 1940 6.457270622253418
# 1941 10.03272533416748
# 1942 -1.907187581062317
# 1943 3.3176639080047607
# 1944 -0.4581144452095032
# 1945 8.882166862487793
# 1946 3.5697126388549805
# 1947 -2.415832757949829
# 1948 6.799441814422607
# 1949 -1.4977794885635376
# 1950 -1.3343313932418823
# 1951 -0.8405342102050781
# 1952 2.8612825870513916
# 1953 0.042740240693092346
# 1954 -4.6426262855529785
# 1955 0.467038631439209
# 1956 10.111603736877441
# 1957 9.200423240661621
# 1958 -0.10337164998054504
# 1959 -2.5665719509124756
# 1960 -1.4700517654418945
# 1961 -0.8094841837882996
# 1962 -3.754286289215088
# 1963 6.044528007507324
# 1964 1.0939974784851074
# 1965 -0.27009254693984985
# 1966 14.20469856262207
# 1967 0.2962103486061096
# 1968 1.0953172445297241
# 1969 1.8296236991882324
# 1970 0.3324218988418579
# 1971 -0.6829935908317566
# 1972 -1.3649297952651978
# 1973 -0.08200705051422119
# 1974 2.329108715057373
# 1975 2.939786911010742
# 1976 8.344675064086914
# 1977 4.910809516906738
# 1978 9.410884857177734
# 1979 6.368401527404785
# 1980 8.478245735168457
# 1981 -1.450260043144226
# 1982 -2.6235430240631104
# 1983 8.04208755493164
# 1984 0.8671773672103882
# 1985 2.2235445976257324
# 1986 7.1110992431640625
# 1987 -0.7966094613075256
# 1988 -0.4421486258506775
# 1989 10.162544250488281
# 1990 -3.225996494293213
# 1991 4.660608291625977
# 1992 4.191869258880615
# 1993 3.4222187995910645
# 1994 5.360498905181885
# 1995 -2.118642568588257
# 1996 1.7283557653427124
# 1997 3.419102430343628
# 1998 0.8927102088928223
# 1999 3.82696533203125
# 2000
# 2

# %%
import pandas as pd
result_df = pd.DataFrame(columns=['Id','Predicted'], data=result_pred)
print(result_df)
# Out:
#         Id  Predicted
# 0        0   5.340230
# 1        1   1.962411
# 2        2   4.263721
# 3        3   4.271944
# 4        4   0.464118
# ...    ...        ...
# 1995  1995  -2.118643
# 1996  1996   1.728356
# 1997  1997   3.419102
# 1998  1998   0.892710
# 1999  1999   3.826965
#
# [2000 rows x 2 columns]

# %%
result_df.to_csv('predictions_nn_lr.csv', index=False)
